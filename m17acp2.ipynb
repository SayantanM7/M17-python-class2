# %% [markdown]
# **Birthdays**

# %%
birthday1 = input("Enter the birthday of student 1 (in the format DD/MM/YYYY): ")
birthday2 = input("Enter the birthday of student 2 (in the format DD/MM/YYYY): ")
birthday3 = input("Enter the birthday of student 3 (in the format DD/MM/YYYY): ")
birthday4 = input("Enter the birthday of student 4 (in the format DD/MM/YYYY): ") 
birthday5 = input("Enter the birthday of student 5 (in the format DD/MM/YYYY): ") 
print("Birthdays of the students:")
print("Student 1:", birthday1)
print("Student 2:", birthday2)
print("Student 3:", birthday3)
print("Student 4:", birthday4) 
print("Student 5:", birthday5)
# Out:
# Enter the birthday of student 1 (in the format DD/MM/YYYY):  01/01/2010
# Enter the birthday of student 2 (in the format DD/MM/YYYY):  02/02/2010
# Enter the birthday of student 3 (in the format DD/MM/YYYY):  03/03/2010
# Enter the birthday of student 4 (in the format DD/MM/YYYY):  04/04/2010
# Enter the birthday of student 5 (in the format DD/MM/YYYY):  05/05/2010
# Birthdays of the students:
# Student 1: 01/01/2010
# Student 2: 02/02/2010
# Student 3: 03/03/2010
# Student 4: 04/04/2010
# Student 5: 05/05/2010
